# %%
import sys

sys.path.append('/home/jp/anaconda3/envs/test_env/lib/python3.8/site-packages')

import os
import glob

#For Images
import cv2
import matplotlib.pyplot as plt
import numpy as np

#For checking progress
from tqdm import tqdm_notebook

import datetime

#PyTorch Packages
import torch
from torch.utils.data.dataset import Dataset
from torchvision import transforms
from torch.utils.data.sampler import SubsetRandomSampler
import torch.nn.functional as F
import torch.optim as optim
import torch.nn as nn

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

os.getcwd()
# Out:
# '/home/jp/Desktop/archive/dataset'

# %%
def get_image(path,transform=False):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    if transform:
        img = transform(img)
    return img

def show_data(rows,cols,is_train=True,transform=False):
    if is_train:
        path = '/home/jp/Desktop/archive/dataset/dataset/train/'
    else:
        path = '/home/jp/Desktop/archive/dataset/dataset/test/'
    path = os.path.join(path,'*orange*','*.png')
    img_paths = glob.glob(path)
    np.random.seed(0)
    img_paths = np.random.choice(img_paths,rows*cols)
    fig = plt.figure(figsize=(8,8),dpi=150)
    i = 1
    for r in range(rows):
        for c in range(cols):
            image_path = img_paths[i-1]
            if 'fresh' in image_path.split('/')[-2]:
                title = 'Fresh'
            else:
                title = 'Rotten'
            ax = fig.add_subplot(rows,cols,i)
            img = get_image(image_path,transform)
            ax.set_xticks([])
            ax.set_yticks([])
            ax.set_title(title,fontsize=5)
            ax.imshow(img)
            i+=1
    return fig

# %%
fig = show_data(5,4, False)
fig.tight_layout()

# %%
fig = show_data(5,4,is_train=False)
fig.tight_layout()

# %%
from PIL import Image



class FruitsDataset(Dataset):
    def __init__(self,path,classifier_type='Rotten',subset='train',transforms=None):
        self.subset = subset
        if self.subset == 'train':
            self.PATH = os.path.join(path,'train','*','*.png')
        elif self.subset == 'test':
            self.PATH = os.path.join(path,'test','*','*.png')
        self.data = glob.glob(self.PATH)
        self.height = 32
        self.width = 32
        self.labels = [] 
        if classifier_type == 'Rotten':
            classes = ['fresh','rotten']
            for fruit in self.data:
                if classes[0] in fruit.split('/')[-2]:
                    self.labels.append(0)
                else:
                    self.labels.append(1)
        else:
            classes = ['apple','banana','orange']
            for fruit in self.data:
                if classes[0] in fruit:
                    self.labels.append(0)
                elif classes[1] in fruit:
                    self.labels.append(1)
                else:
                    self.labels.append(2)
        self.transforms = transforms
      
    def __getitem__(self,index):
        img_path = self.data[index]
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img = cv2.resize(img,(self.width,self.height))
        label = self.labels[index]
        if self.transforms is not None:
            img_as_tensor = self.transforms(Image.fromarray(img))
            if self.transforms is not None:
                return(img_as_tensor,label)
            return(img,label)
  
    def __len__(self):
        return(len(self.data))

# %%
transformations = transforms.Compose([                                      
                                      transforms.RandomResizedCrop(224),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.7321, 0.6322, 0.5291),
                                                           (0.3302, 0.3432, 0.3701))
                                      ])
dataset = FruitsDataset('/home/jp/Desktop/archive/dataset/dataset/',transforms = transformations)

# %%
print(dataset[2])
img_t, _ = dataset[2]
img = img_t.permute(1,2,0)
plt.imshow(img);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (tensor([[[-0.1150, -0.1150, -0.1150,  ...,  0.0156,  0.0156,  0.0156],
#          [-0.1150, -0.1150, -0.1150,  ...,  0.0156,  0.0156,  0.0156],
#          [-0.1150, -0.1150, -0.1150,  ...,  0.0156,  0.0156,  0.0156],
#          ...,
#          [-0.4594, -0.4594, -0.4594,  ..., -0.0200, -0.0200, -0.0200],
#          [-0.4594, -0.4594, -0.4594,  ..., -0.0200, -0.0200, -0.0200],
#          [-0.4594, -0.4594, -0.4594,  ..., -0.0200, -0.0200, -0.0200]],
#
#         [[-0.8137, -0.8137, -0.8137,  ...,  0.3404,  0.3404,  0.3404],
#          [-0.8137, -0.8137, -0.8137,  ...,  0.3404,  0.3404,  0.3404],
#          [-0.8137, -0.8137, -0.8137,  ...,  0.3404,  0.3404,  0.3404],
#          ...,
#          [-0.2309, -0.2309, -0.2309,  ...,  0.1347,  0.1347,  0.1347],
#          [-0.2309, -0.2309, -0.2309,  ...,  0.1347,  0.1347,  0.1347],
#          [-0.2309, -0.2309, -0.2309,  ...,  0.1347,  0.1347,  0.1347]],
#
#         [[-1.0694, -1.0694, -1.0694,  ...,  0.6578,  0.6578,  0.6578],
#          [-1.0694, -1.0694, -1.0694,  ...,  0.6578,  0.6578,  0.6578],
#          [-1.0694, -1.0694, -1.0694,  ...,  0.6578,  0.6578,  0.6578],
#          ...,
#          [-0.0203, -0.0203, -0.0203,  ...,  0.4035,  0.4035,  0.4035],
#          [-0.0203, -0.0203, -0.0203,  ...,  0.4035,  0.4035,  0.4035],
#          [-0.0203, -0.0203, -0.0203,  ...,  0.4035,  0.4035,  0.4035]]]), 1)

# %%
batch_size = 64
validation_split = .2
shuffle_dataset = True
random_seed= 42

# Creating data indices for training and validation splits:
dataset_size = len(dataset)
print(dataset_size)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
                                           sampler=train_sampler)
validation_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                sampler=valid_sampler)
# Out:
# 3061

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3,16,kernel_size=3,padding=1)
        self.conv2 = nn.Conv2d(16,8,kernel_size=3,padding=1)
        self.fc1 = nn.Linear(8*8*8,32)
        self.fc2 = nn.Linear(32,2)
    def forward(self,x):
        out = F.max_pool2d(torch.tanh(self.conv1(x)),2)
        out = F.max_pool2d(torch.tanh(self.conv2(out)),2)
        out = out.view(-1,8*8*8)
        out = torch.tanh(self.fc1(out))
        out = self.fc2(out)
        return out

# %%
model = Net()
numel_list = [p.numel() for p in model.parameters()]
sum(numel_list), numel_list
# Out:
# (18090, [432, 16, 1152, 8, 16384, 32, 64, 2])

# %%
device = (torch.device('cuda') if torch.cuda.is_available()
  else torch.device('cpu'))
print(f"Training on device {device}.")
# Out:
# Training on device cuda.

# %%
def training_loop(n_epochs,optimizer,model,loss_fn,train_loader):
    for epoch in tqdm_notebook(range(1,n_epochs+1)):
        loss_train = 0.0
        for imgs, labels in train_loader:
            imgs = imgs.to(device=device)
            labels = labels.to(device=device)
            outputs = model(imgs)
            loss = loss_fn(outputs,labels)
            #get rid of gradients from last round
            optimizer.zero_grad()
            #performs backward step. Computes all the gradients
            loss.backward()
            #Updates the model
            optimizer.step()
            loss_train += loss.item()
        print('{} Epoch {}, Training Loop {}'.format(
          datetime.datetime.now(), epoch, loss_train/len(train_loader)))

model = Net().to(device=device) #was talking about this above
optimizer = optim.SGD(model.parameters(), lr=1e-2)
loss_fn = nn.CrossEntropyLoss()
training_loop(
  n_epochs = 25,
  optimizer = optimizer,
  model = model,
  loss_fn = loss_fn,
  train_loader = train_loader,
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-237-4fb805ac1311> in <module>
#      17           datetime.datetime.now(), epoch, loss_train/len(train_loader)))
#      18
# ---> 19 model = Net().to(device=device) #was talking about this above
#      20 optimizer = optim.SGD(model.parameters(), lr=1e-2)
#      21 loss_fn = nn.CrossEntropyLoss()
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#     605             return t.to(device, dtype if t.is_floating_point() else None, non_blocking)
#     606
# --> 607         return self._apply(convert)
#     608
#     609     def register_backward_hook(
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     352     def _apply(self, fn):
#     353         for module in self.children():
# --> 354             module._apply(fn)
#     355
#     356         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     374                 # `with torch.no_grad():`
#     375                 with torch.no_grad():
# --> 376                     param_applied = fn(param)
#     377                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     378                 if should_use_set_data:
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in convert(t)
#     603             if convert_to_format is not None and t.dim() == 4:
#     604                 return t.to(device, dtype if t.is_floating_point() else None, non_blocking, memory_format=convert_to_format)
# --> 605             return t.to(device, dtype if t.is_floating_point() else None, non_blocking)
#     606
#     607         return self._apply(convert)
#
# RuntimeError: CUDA error: unspecified launch failure

# %%
torch.save(model.state_dict(), 'FreshnessDetector.pt')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-232-b969b6650620> in <module>
# ----> 1 torch.save(model.state_dict(), 'FreshnessDetector.pt')
#
# ~/anaconda3/lib/python3.8/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     362         if _use_new_zipfile_serialization:
#     363             with _open_zipfile_writer(opened_file) as opened_zipfile:
# --> 364                 _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     365                 return
#     366         _legacy_save(obj, opened_file, pickle_module, pickle_protocol)
#
# ~/anaconda3/lib/python3.8/site-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol)
#     479             # Copy to a buffer, then serialize that
#     480             buf = io.BytesIO()
# --> 481             storage._write_file(buf, _should_read_directly(buf))
#     482             buf_value = buf.getvalue()
#     483             zip_file.write_record(name, buf_value, len(buf_value))
#
# RuntimeError: cuda runtime error (719) : unspecified launch failure at /pytorch/torch/csrc/generic/serialization.cpp:31

# %%
def validate(model,train_loader,val_loader):
    for name, loader in [('train',train_loader),('val',validation_loader)]:
        correct = 0
        total = 0

        #gradients nor required, as we don't want to train our parameters
        with torch.no_grad():
            for imgs, labels in loader:
                imgs = imgs.to(device=device)
                labels = labels.to(device=device)
                outputs = model(imgs)
                #max_index,value
                _,predicted = torch.max(outputs,dim=1)
                total+=labels.shape[0]
                correct+=int((predicted==labels).sum())
    
        print('Accuracy {}: {:.2f}'.format(name, correct/total))

validate(model,train_loader,validation_loader)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-240-f2625e846b88> in <module>
#      17         print('Accuracy {}: {:.2f}'.format(name, correct/total))
#      18
# ---> 19 validate(model,train_loader,validation_loader)
#
# <ipython-input-240-f2625e846b88> in validate(model, train_loader, val_loader)
#       7         with torch.no_grad():
#       8             for imgs, labels in loader:
# ----> 9                 imgs = imgs.to(device=device)
#      10                 labels = labels.to(device=device)
#      11                 outputs = model(imgs)
#
# RuntimeError: CUDA error: unspecified launch failure

# %%
img,label = dataset[1]
plt.imshow(img.permute(1,2,0))
out = model(img.unsqueeze(0).to(device))
print('Actual: {}'.format(label))
print('Prediction: {}'.format(out))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-241-4f9bd8fd358b> in <module>
#       1 img,label = dataset[1]
#       2 plt.imshow(img.permute(1,2,0))
# ----> 3 out = model(img.unsqueeze(0).to(device))
#       4 print('Actual: {}'.format(label))
#       5 print('Prediction: {}'.format(out))
#
# RuntimeError: CUDA error: unspecified launch failure

# %%
transformations_test = transforms.Compose([
   transforms.RandomHorizontalFlip(),
   transforms.ToTensor(),
   transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
   transforms.RandomErasing(),
 ])

test = FruitsDataset('/home/jp/Desktop/archive/dataset/dataset/',subset='test',transforms=transformations_test)
print(len(test))
print(test[0])
# Out:
# 791
# (tensor([[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#          [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#          [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#          ...,
#          [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#          [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#          [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#         [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#          [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#          [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#          ...,
#          [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#          [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#          [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#         [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          ...,
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]]), 1)

# %%
import time

start_time = time.time()
count=0
for img,_ in test:
    #plt.imshow(img.permute(1,2,0))
    count = count + 1
    print(count)
    s = nn.Softmax(dim=1)
    out = s(model(img.unsqueeze(0).to(device)))
    #print('Prediction: {}'.format(out))

    _,predicted = torch.max(out,dim=1)

    if(predicted.data.cpu().numpy()[0]==1):
        print('LARANJA PODRE')
    if(predicted.data.cpu().numpy()[0]==0):
        print('LARANJA BOA')
    

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 1
# LARANJA PODRE
# 2
# LARANJA BOA
# 3
# LARANJA PODRE
# 4
# LARANJA PODRE
# 5
# LARANJA BOA
# 6
# LARANJA BOA
# 7
# LARANJA PODRE
# 8
# LARANJA BOA
# 9
# LARANJA PODRE
# 10
# LARANJA PODRE
# 11
# LARANJA PODRE
# 12
# LARANJA PODRE
# 13
# LARANJA PODRE
# 14
# LARANJA PODRE
# 15
# LARANJA PODRE
# 16
# LARANJA PODRE
# 17
# LARANJA PODRE
# 18
# LARANJA BOA
# 19
# LARANJA PODRE
# 20
# LARANJA BOA
# 21
# LARANJA PODRE
# 22
# LARANJA BOA
# 23
# LARANJA PODRE
# 24
# LARANJA PODRE
# 25
# LARANJA PODRE
# 26
# LARANJA PODRE
# 27
# LARANJA PODRE
# 28
# LARANJA PODRE
# 29
# LARANJA PODRE
# 30
# LARANJA PODRE
# 31
# LARANJA PODRE
# 32
# LARANJA BOA
# 33
# LARANJA PODRE
# 34
# LARANJA BOA
# 35
# LARANJA PODRE
# 36
# LARANJA PODRE
# 37
# LARANJA BOA
# 38
# LARANJA PODRE
# 39
# LARANJA PODRE
# 40
# LARANJA BOA
# 41
# LARANJA BOA
# 42
# LARANJA PODRE
# 43
# LARANJA PODRE
# 44
# LARANJA PODRE
# 45
# LARANJA PODRE
# 46
# LARANJA BOA
# 47
# LARANJA PODRE
# 48
# LARANJA PODRE
# 49
# LARANJA PODRE
# 50
# LARANJA BOA
# 51
# LARANJA PODRE
# 52
# LARANJA BOA
# 53
# LARANJA PODRE
# 54
# LARANJA PODRE
# 55
# LARANJA BOA
# 56
# LARANJA PODRE
# 57
# LARANJA PODRE
# 58
# LARANJA PODRE
# 59
# LARANJA BOA
# 60
# LARANJA PODRE
# 61
# LARANJA PODRE
# 62
# LARANJA PODRE
# 63
# LARANJA PODRE
# 64
# LARANJA BOA
# 65
# LARANJA BOA
# 66
# LARANJA PODRE
# 67
# LARANJA PODRE
# 68
# LARANJA BOA
# 69
# LARANJA BOA
# 70
# LARANJA BOA
# 71
# LARANJA PODRE
# 72
# LARANJA BOA
# 73
# LARANJA BOA
# 74
# LARANJA PODRE
# 75
# LARANJA PODRE
# 76
# LARANJA PODRE
# 77
# LARANJA PODRE
# 78
# LARANJA BOA
# 79
# LARANJA PODRE
# 80
# LARANJA PODRE
# 81
# LARANJA PODRE
# 82
# LARANJA PODRE
# 83
# LARANJA PODRE
# 84
# LARANJA PODRE
# 85
# LARANJA PODRE
# 86
# LARANJA PODRE
# 87
# LARANJA BOA
# 88
# LARANJA BOA
# 89
# LARANJA PODRE
# 90
# LARANJA PODRE
# 91
# LARANJA PODRE
# 92
# LARANJA PODRE
# 93
# LARANJA BOA
# 94
# LARANJA PODRE
# 95
# LARANJA PODRE
# 96
# LARANJA PODRE
# 97
# LARANJA BOA
# 98
# LARANJA PODRE
# 99
# LARANJA PODRE
# 100
# LARANJA PODRE
# 101
# LARANJA PODRE
# 102
# LARANJA PODRE
# 103
# LARANJA PODRE
# 104
# LARANJA BOA
# 105
# LARANJA PODRE
# 106
# LARANJA PODRE
# 107
# LARANJA BOA
# 108
# LARANJA BOA
# 109
# LARANJA PODRE
# 110
# LARANJA PODRE
# 111
# LARANJA BOA
# 112
# LARANJA PODRE
# 113
# LARANJA BOA
# 114
# LARANJA PODRE
# 115
# LARANJA BOA
# 116
# LARANJA PODRE
# 117
# LARANJA PODRE
# 118
# LARANJA PODRE
# 119
# LARANJA PODRE
# 120
# LARANJA PODRE
# 121
# LARANJA PODRE
# 122
# LARANJA PODRE
# 123
# LARANJA PODRE
# 124
# LARANJA PODRE
# 125
# LARANJA PODRE
# 126
# LARANJA PODRE
# 127
# LARANJA BOA
# 128
# LARANJA PODRE
# 129
# LARANJA PODRE
# 130
# LARANJA PODRE
# 131
# LARANJA PODRE
# 132
# LARANJA PODRE
# 133
# LARANJA PODRE
# 134
# LARANJA PODRE
# 135
# LARANJA BOA
# 136
# LARANJA PODRE
# 137
# LARANJA BOA
# 138
# LARANJA BOA
# 139
# LARANJA BOA
# 140
# LARANJA PODRE
# 141
# LARANJA PODRE
# 142
# LARANJA PODRE
# 143
# LARANJA PODRE
# 144
# LARANJA PODRE
# 145
# LARANJA BOA
# 146
# LARANJA PODRE
# 147
# LARANJA PODRE
# 148
# LARANJA PODRE
# 149
# LARANJA PODRE
# 150
# LARANJA BOA
# 151
# LARANJA PODRE
# 152
# LARANJA PODRE
# 153
# LARANJA BOA
# 154
# LARANJA PODRE
# 155
# LARANJA PODRE
# 156
# LARANJA PODRE
# 157
# LARANJA PODRE
# 158
# LARANJA BOA
# 159
# LARANJA PODRE
# 160
# LARANJA PODRE
# 161
# LARANJA BOA
# 162
# LARANJA PODRE
# 163
# LARANJA PODRE
# 164
# LARANJA PODRE
# 165
# LARANJA BOA
# 166
# LARANJA BOA
# 167
# LARANJA PODRE
# 168
# LARANJA BOA
# 169
# LARANJA BOA
# 170
# LARANJA PODRE
# 171
# LARANJA PODRE
# 172
# LARANJA PODRE
# 173
# LARANJA PODRE
# 174
# LARANJA BOA
# 175
# LARANJA PODRE
# 176
# LARANJA BOA
# 177
# LARANJA PODRE
# 178
# LARANJA PODRE
# 179
# LARANJA BOA
# 180
# LARANJA PODRE
# 181
# LARANJA PODRE
# 182
# LARANJA PODRE
# 183
# LARANJA PODRE
# 184
# LARANJA PODRE
# 185
# LARANJA PODRE
# 186
# LARANJA PODRE
# 187
# LARANJA BOA
# 188
# LARANJA PODRE
# 189
# LARANJA PODRE
# 190
# LARANJA PODRE
# 191
# LARANJA PODRE
# 192
# LARANJA BOA
# 193
# LARANJA PODRE
# 194
# LARANJA BOA
# 195
# LARANJA PODRE
# 196
# LARANJA BOA
# 197
# LARANJA PODRE
# 198
# LARANJA PODRE
# 199
# LARANJA PODRE
# 200
# LARANJA BOA
# 201
# LARANJA PODRE
# 202
# LARANJA PODRE
# 203
# LARANJA PODRE
# 204
# LARANJA PODRE
# 205
# LARANJA PODRE
# 206
# LARANJA PODRE
# 207
# LARANJA PODRE
# 208
# LARANJA PODRE
# 209
# LARANJA PODRE
# 210
# LARANJA PODRE
# 211
# LARANJA PODRE
# 212
# LARANJA BOA
# 213
# LARANJA BOA
# 214
# LARANJA PODRE
# 215
# LARANJA PODRE
# 216
# LARANJA PODRE
# 217
# LARANJA PODRE
# 218
# LARANJA PODRE
# 219
# LARANJA PODRE
# 220
# LARANJA PODRE
# 221
# LARANJA PODRE
# 222
# LARANJA PODRE
# 223
# LARANJA PODRE
# 224
# LARANJA PODRE
# 225
# LARANJA BOA
# 226
# LARANJA PODRE
# 227
# LARANJA PODRE
# 228
# LARANJA PODRE
# 229
# LARANJA PODRE
# 230
# LARANJA BOA
# 231
# LARANJA PODRE
# 232
# LARANJA PODRE
# 233
# LARANJA BOA
# 234
# LARANJA PODRE
# 235
# LARANJA BOA
# 236
# LARANJA PODRE
# 237
# LARANJA PODRE
# 238
# LARANJA BOA
# 239
# LARANJA BOA
# 240
# LARANJA PODRE
# 241
# LARANJA PODRE
# 242
# LARANJA PODRE
# 243
# LARANJA PODRE
# 244
# LARANJA BOA
# 245
# LARANJA BOA
# 246
# LARANJA PODRE
# 247
# LARANJA BOA
# 248
# LARANJA BOA
# 249
# LARANJA BOA
# 250
# LARANJA PODRE
# 251
# LARANJA PODRE
# 252
# LARANJA PODRE
# 253
# LARANJA PODRE
# 254
# LARANJA BOA
# 255
# LARANJA PODRE
# 256
# LARANJA BOA
# 257
# LARANJA PODRE
# 258
# LARANJA PODRE
# 259
# LARANJA PODRE
# 260
# LARANJA PODRE
# 261
# LARANJA PODRE
# 262
# LARANJA PODRE
# 263
# LARANJA PODRE
# 264
# LARANJA PODRE
# 265
# LARANJA PODRE
# 266
# LARANJA PODRE
# 267
# LARANJA BOA
# 268
# LARANJA BOA
# 269
# LARANJA BOA
# 270
# LARANJA PODRE
# 271
# LARANJA BOA
# 272
# LARANJA BOA
# 273
# LARANJA PODRE
# 274
# LARANJA PODRE
# 275
# LARANJA BOA
# 276
# LARANJA PODRE
# 277
# LARANJA PODRE
# 278
# LARANJA PODRE
# 279
# LARANJA PODRE
# 280
# LARANJA PODRE
# 281
# LARANJA PODRE
# 282
# LARANJA PODRE
# 283
# LARANJA PODRE
# 284
# LARANJA PODRE
# 285
# LARANJA PODRE
# 286
# LARANJA PODRE
# 287
# LARANJA BOA
# 288
# LARANJA BOA
# 289
# LARANJA PODRE
# 290
# LARANJA PODRE
# 291
# LARANJA PODRE
# 292
# LARANJA PODRE
# 293
# LARANJA PODRE
# 294
# LARANJA PODRE
# 295
# LARANJA PODRE
# 296
# LARANJA PODRE
# 297
# LARANJA BOA
# 298
# LARANJA PODRE
# 299
# LARANJA PODRE
# 300
# LARANJA PODRE
# 301
# LARANJA PODRE
# 302
# LARANJA PODRE
# 303
# LARANJA PODRE
# 304
# LARANJA PODRE
# 305
# LARANJA PODRE
# 306
# LARANJA BOA
# 307
# LARANJA BOA
# 308
# LARANJA PODRE
# 309
# LARANJA PODRE
# 310
# LARANJA BOA
# 311
# LARANJA PODRE
# 312
# LARANJA PODRE
# 313
# LARANJA PODRE
# 314
# LARANJA PODRE
# 315
# LARANJA PODRE
# 316
# LARANJA PODRE
# 317
# LARANJA BOA
# 318
# LARANJA BOA
# 319
# LARANJA PODRE
# 320
# LARANJA PODRE
# 321
# LARANJA BOA
# 322
# LARANJA PODRE
# 323
# LARANJA PODRE
# 324
# LARANJA PODRE
# 325
# LARANJA BOA
# 326
# LARANJA PODRE
# 327
# LARANJA BOA
# 328
# LARANJA PODRE
# 329
# LARANJA PODRE
# 330
# LARANJA BOA
# 331
# LARANJA PODRE
# 332
# LARANJA PODRE
# 333
# LARANJA PODRE
# 334
# LARANJA PODRE
# 335
# LARANJA PODRE
# 336
# LARANJA PODRE
# 337
# LARANJA PODRE
# 338
# LARANJA PODRE
# 339
# LARANJA PODRE
# 340
# LARANJA BOA
# 341
# LARANJA BOA
# 342
# LARANJA BOA
# 343
# LARANJA PODRE
# 344
# LARANJA PODRE
# 345
# LARANJA PODRE
# 346
# LARANJA PODRE
# 347
# LARANJA BOA
# 348
# LARANJA BOA
# 349
# LARANJA BOA
# 350
# LARANJA PODRE
# 351
# LARANJA PODRE
# 352
# LARANJA BOA
# 353
# LARANJA PODRE
# 354
# LARANJA BOA
# 355
# LARANJA PODRE
# 356
# LARANJA BOA
# 357
# LARANJA BOA
# 358
# LARANJA PODRE
# 359
# LARANJA BOA
# 360
# LARANJA BOA
# 361
# LARANJA PODRE
# 362
# LARANJA PODRE
# 363
# LARANJA PODRE
# 364
# LARANJA PODRE
# 365
# LARANJA PODRE
# 366
# LARANJA BOA
# 367
# LARANJA PODRE
# 368
# LARANJA PODRE
# 369
# LARANJA PODRE
# 370
# LARANJA BOA
# 371
# LARANJA PODRE
# 372
# LARANJA BOA
# 373
# LARANJA BOA
# 374
# LARANJA PODRE
# 375
# LARANJA PODRE
# 376
# LARANJA BOA
# 377
# LARANJA PODRE
# 378
# LARANJA BOA
# 379
# LARANJA PODRE
# 380
# LARANJA BOA
# 381
# LARANJA PODRE
# 382
# LARANJA PODRE
# 383
# LARANJA PODRE
# 384
# LARANJA PODRE
# 385
# LARANJA PODRE
# 386
# LARANJA PODRE
# 387
# LARANJA PODRE
# 388
# LARANJA PODRE
# 389
# LARANJA PODRE
# 390
# LARANJA BOA
# 391
# LARANJA PODRE
# 392
# LARANJA PODRE
# 393
# LARANJA PODRE
# 394
# LARANJA PODRE
# 395
# LARANJA PODRE
# 396
# LARANJA PODRE
# 397
# LARANJA BOA
# 398
# LARANJA PODRE
# 399
# LARANJA PODRE
# 400
# LARANJA BOA
# 401
# LARANJA BOA
# 402
# LARANJA BOA
# 403
# LARANJA PODRE
# 404
# LARANJA BOA
# 405
# LARANJA BOA
# 406
# LARANJA BOA
# 407
# LARANJA BOA
# 408
# LARANJA BOA
# 409
# LARANJA BOA
# 410
# LARANJA BOA
# 411
# LARANJA BOA
# 412
# LARANJA BOA
# 413
# LARANJA BOA
# 414
# LARANJA BOA
# 415
# LARANJA BOA
# 416
# LARANJA BOA
# 417
# LARANJA BOA
# 418
# LARANJA PODRE
# 419
# LARANJA BOA
# 420
# LARANJA PODRE
# 421
# LARANJA PODRE
# 422
# LARANJA BOA
# 423
# LARANJA PODRE
# 424
# LARANJA PODRE
# 425
# LARANJA BOA
# 426
# LARANJA BOA
# 427
# LARANJA BOA
# 428
# LARANJA BOA
# 429
# LARANJA BOA
# 430
# LARANJA BOA
# 431
# LARANJA PODRE
# 432
# LARANJA BOA
# 433
# LARANJA BOA
# 434
# LARANJA BOA
# 435
# LARANJA BOA
# 436
# LARANJA BOA
# 437
# LARANJA BOA
# 438
# LARANJA BOA
# 439
# LARANJA BOA
# 440
# LARANJA PODRE
# 441
# LARANJA BOA
# 442
# LARANJA PODRE
# 443
# LARANJA BOA
# 444
# LARANJA BOA
# 445
# LARANJA PODRE
# 446
# LARANJA PODRE
# 447
# LARANJA BOA
# 448
# LARANJA BOA
# 449
# LARANJA PODRE
# 450
# LARANJA BOA
# 451
# LARANJA BOA
# 452
# LARANJA BOA
# 453
# LARANJA BOA
# 454
# LARANJA BOA
# 455
# LARANJA BOA
# 456
# LARANJA BOA
# 457
# LARANJA BOA
# 458
# LARANJA BOA
# 459
# LARANJA BOA
# 460
# LARANJA BOA
# 461
# LARANJA BOA
# 462
# LARANJA BOA
# 463
# LARANJA BOA
# 464
# LARANJA BOA
# 465
# LARANJA BOA
# 466
# LARANJA BOA
# 467
# LARANJA BOA
# 468
# LARANJA BOA
# 469
# LARANJA PODRE
# 470
# LARANJA BOA
# 471
# LARANJA BOA
# 472
# LARANJA BOA
# 473
# LARANJA BOA
# 474
# LARANJA BOA
# 475
# LARANJA BOA
# 476
# LARANJA BOA
# 477
# LARANJA BOA
# 478
# LARANJA BOA
# 479
# LARANJA BOA
# 480
# LARANJA BOA
# 481
# LARANJA PODRE
# 482
# LARANJA BOA
# 483
# LARANJA BOA
# 484
# LARANJA PODRE
# 485
# LARANJA BOA
# 486
# LARANJA PODRE
# 487
# LARANJA BOA
# 488
# LARANJA BOA
# 489
# LARANJA BOA
# 490
# LARANJA BOA
# 491
# LARANJA BOA
# 492
# LARANJA BOA
# 493
# LARANJA BOA
# 494
# LARANJA BOA
# 495
# LARANJA BOA
# 496
# LARANJA BOA
# 497
# LARANJA BOA
# 498
# LARANJA BOA
# 499
# LARANJA BOA
# 500
# LARANJA BOA
# 501
# LARANJA BOA
# 502
# LARANJA BOA
# 503
# LARANJA BOA
# 504
# LARANJA BOA
# 505
# LARANJA BOA
# 506
# LARANJA PODRE
# 507
# LARANJA BOA
# 508
# LARANJA BOA
# 509
# LARANJA BOA
# 510
# LARANJA BOA
# 511
# LARANJA BOA
# 512
# LARANJA PODRE
# 513
# LARANJA BOA
# 514
# LARANJA BOA
# 515
# LARANJA BOA
# 516
# LARANJA BOA
# 517
# LARANJA PODRE
# 518
# LARANJA BOA
# 519
# LARANJA BOA
# 520
# LARANJA BOA
# 521
# LARANJA BOA
# 522
# LARANJA PODRE
# 523
# LARANJA BOA
# 524
# LARANJA BOA
# 525
# LARANJA BOA
# 526
# LARANJA PODRE
# 527
# LARANJA BOA
# 528
# LARANJA BOA
# 529
# LARANJA BOA
# 530
# LARANJA BOA
# 531
# LARANJA BOA
# 532
# LARANJA BOA
# 533
# LARANJA BOA
# 534
# LARANJA BOA
# 535
# LARANJA BOA
# 536
# LARANJA BOA
# 537
# LARANJA BOA
# 538
# LARANJA BOA
# 539
# LARANJA BOA
# 540
# LARANJA PODRE
# 541
# LARANJA BOA
# 542
# LARANJA BOA
# 543
# LARANJA PODRE
# 544
# LARANJA PODRE
# 545
# LARANJA BOA
# 546
# LARANJA BOA
# 547
# LARANJA BOA
# 548
# LARANJA BOA
# 549
# LARANJA BOA
# 550
# LARANJA BOA
# 551
# LARANJA BOA
# 552
# LARANJA BOA
# 553
# LARANJA BOA
# 554
# LARANJA PODRE
# 555
# LARANJA PODRE
# 556
# LARANJA BOA
# 557
# LARANJA BOA
# 558
# LARANJA BOA
# 559
# LARANJA BOA
# 560
# LARANJA BOA
# 561
# LARANJA BOA
# 562
# LARANJA PODRE
# 563
# LARANJA PODRE
# 564
# LARANJA BOA
# 565
# LARANJA BOA
# 566
# LARANJA BOA
# 567
# LARANJA BOA
# 568
# LARANJA BOA
# 569
# LARANJA BOA
# 570
# LARANJA BOA
# 571
# LARANJA BOA
# 572
# LARANJA PODRE
# 573
# LARANJA BOA
# 574
# LARANJA PODRE
# 575
# LARANJA BOA
# 576
# LARANJA BOA
# 577
# LARANJA PODRE
# 578
# LARANJA BOA
# 579
# LARANJA BOA
# 580
# LARANJA BOA
# 581
# LARANJA BOA
# 582
# LARANJA BOA
# 583
# LARANJA BOA
# 584
# LARANJA BOA
# 585
# LARANJA BOA
# 586
# LARANJA PODRE
# 587
# LARANJA PODRE
# 588
# LARANJA BOA
# 589
# LARANJA BOA
# 590
# LARANJA PODRE
# 591
# LARANJA BOA
# 592
# LARANJA BOA
# 593
# LARANJA BOA
# 594
# LARANJA PODRE
# 595
# LARANJA BOA
# 596
# LARANJA BOA
# 597
# LARANJA BOA
# 598
# LARANJA BOA
# 599
# LARANJA BOA
# 600
# LARANJA BOA
# 601
# LARANJA BOA
# 602
# LARANJA BOA
# 603
# LARANJA BOA
# 604
# LARANJA BOA
# 605
# LARANJA PODRE
# 606
# LARANJA BOA
# 607
# LARANJA BOA
# 608
# LARANJA BOA
# 609
# LARANJA BOA
# 610
# LARANJA BOA
# 611
# LARANJA BOA
# 612
# LARANJA BOA
# 613
# LARANJA BOA
# 614
# LARANJA BOA
# 615
# LARANJA BOA
# 616
# LARANJA BOA
# 617
# LARANJA BOA
# 618
# LARANJA BOA
# 619
# LARANJA PODRE
# 620
# LARANJA BOA
# 621
# LARANJA BOA
# 622
# LARANJA BOA
# 623
# LARANJA BOA
# 624
# LARANJA BOA
# 625
# LARANJA BOA
# 626
# LARANJA BOA
# 627
# LARANJA BOA
# 628
# LARANJA BOA
# 629
# LARANJA PODRE
# 630
# LARANJA BOA
# 631
# LARANJA BOA
# 632
# LARANJA BOA
# 633
# LARANJA BOA
# 634
# LARANJA PODRE
# 635
# LARANJA PODRE
# 636
# LARANJA BOA
# 637
# LARANJA PODRE
# 638
# LARANJA BOA
# 639
# LARANJA BOA
# 640
# LARANJA BOA
# 641
# LARANJA BOA
# 642
# LARANJA BOA
# 643
# LARANJA BOA
# 644
# LARANJA BOA
# 645
# LARANJA BOA
# 646
# LARANJA BOA
# 647
# LARANJA BOA
# 648
# LARANJA BOA
# 649
# LARANJA BOA
# 650
# LARANJA BOA
# 651
# LARANJA BOA
# 652
# LARANJA BOA
# 653
# LARANJA BOA
# 654
# LARANJA BOA
# 655
# LARANJA PODRE
# 656
# LARANJA BOA
# 657
# LARANJA BOA
# 658
# LARANJA BOA
# 659
# LARANJA BOA
# 660
# LARANJA BOA
# 661
# LARANJA BOA
# 662
# LARANJA PODRE
# 663
# LARANJA BOA
# 664
# LARANJA BOA
# 665
# LARANJA BOA
# 666
# LARANJA BOA
# 667
# LARANJA BOA
# 668
# LARANJA BOA
# 669
# LARANJA BOA
# 670
# LARANJA BOA
# 671
# LARANJA BOA
# 672
# LARANJA BOA
# 673
# LARANJA BOA
# 674
# LARANJA PODRE
# 675
# LARANJA BOA
# 676
# LARANJA PODRE
# 677
# LARANJA BOA
# 678
# LARANJA PODRE
# 679
# LARANJA BOA
# 680
# LARANJA BOA
# 681
# LARANJA BOA
# 682
# LARANJA BOA
# 683
# LARANJA BOA
# 684
# LARANJA BOA
# 685
# LARANJA PODRE
# 686
# LARANJA BOA
# 687
# LARANJA BOA
# 688
# LARANJA BOA
# 689
# LARANJA BOA
# 690
# LARANJA BOA
# 691
# LARANJA BOA
# 692
# LARANJA BOA
# 693
# LARANJA BOA
# 694
# LARANJA BOA
# 695
# LARANJA BOA
# 696
# LARANJA BOA
# 697
# LARANJA BOA
# 698
# LARANJA BOA
# 699
# LARANJA BOA
# 700
# LARANJA BOA
# 701
# LARANJA BOA
# 702
# LARANJA BOA
# 703
# LARANJA BOA
# 704
# LARANJA BOA
# 705
# LARANJA BOA
# 706
# LARANJA BOA
# 707
# LARANJA BOA
# 708
# LARANJA PODRE
# 709
# LARANJA BOA
# 710
# LARANJA BOA
# 711
# LARANJA BOA
# 712
# LARANJA PODRE
# 713
# LARANJA PODRE
# 714
# LARANJA PODRE
# 715
# LARANJA BOA
# 716
# LARANJA BOA
# 717
# LARANJA BOA
# 718
# LARANJA BOA
# 719
# LARANJA BOA
# 720
# LARANJA PODRE
# 721
# LARANJA BOA
# 722
# LARANJA BOA
# 723
# LARANJA BOA
# 724
# LARANJA BOA
# 725
# LARANJA BOA
# 726
# LARANJA BOA
# 727
# LARANJA BOA
# 728
# LARANJA BOA
# 729
# LARANJA BOA
# 730
# LARANJA BOA
# 731
# LARANJA BOA
# 732
# LARANJA PODRE
# 733
# LARANJA PODRE
# 734
# LARANJA BOA
# 735
# LARANJA BOA
# 736
# LARANJA BOA
# 737
# LARANJA BOA
# 738
# LARANJA BOA
# 739
# LARANJA BOA
# 740
# LARANJA BOA
# 741
# LARANJA BOA
# 742
# LARANJA BOA
# 743
# LARANJA BOA
# 744
# LARANJA BOA
# 745
# LARANJA PODRE
# 746
# LARANJA BOA
# 747
# LARANJA BOA
# 748
# LARANJA BOA
# 749
# LARANJA BOA
# 750
# LARANJA BOA
# 751
# LARANJA BOA
# 752
# LARANJA BOA
# 753
# LARANJA BOA
# 754
# LARANJA BOA
# 755
# LARANJA BOA
# 756
# LARANJA BOA
# 757
# LARANJA BOA
# 758
# LARANJA BOA
# 759
# LARANJA BOA
# 760
# LARANJA BOA
# 761
# LARANJA BOA
# 762
# LARANJA BOA
# 763
# LARANJA BOA
# 764
# LARANJA BOA
# 765
# LARANJA BOA
# 766
# LARANJA BOA
# 767
# LARANJA BOA
# 768
# LARANJA BOA
# 769
# LARANJA BOA
# 770
# LARANJA PODRE
# 771
# LARANJA BOA
# 772
# LARANJA BOA
# 773
# LARANJA BOA
# 774
# LARANJA BOA
# 775
# LARANJA BOA
# 776
# LARANJA BOA
# 777
# LARANJA BOA
# 778
# LARANJA BOA
# 779
# LARANJA BOA
# 780
# LARANJA BOA
# 781
# LARANJA PODRE
# 782
# LARANJA BOA
# 783
# LARANJA BOA
# 784
# LARANJA BOA
# 785
# LARANJA BOA
# 786
# LARANJA BOA
# 787
# LARANJA BOA
# 788
# LARANJA BOA
# 789
# LARANJA BOA
# 790
# LARANJA BOA
# 791
# LARANJA PODRE
# --- 2.998159408569336 seconds ---

# %% [markdown]
# ## correct = 0
# total = 0
# test_loader = torch.utils.data.DataLoader(test, batch_size=batch_size)
# for imgs, labels in train_loader:
#     imgs = imgs.to(device=device)
#     labels = labels.to(device=device)
#     out = model(imgs)
#     _,predicted = torch.max(out,dim=1)
#     print(labels)
#     correct += int((predicted==labels).sum())
#     total += len(labels)

# %%
(correct/total)*100
# Out:
# 90.52674561045325

# %%
import torch
from torchvision.transforms import transforms
from PIL import Image
from pathlib import Path

model = Net().to(device=device) #was talking about this above
checkpoint = torch.load(Path('/home/jp/Desktop/archive/dataset/FreshnessDetector.pt'))
model.load_state_dict(checkpoint)

transformations = transforms.Compose([
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.7321, 0.6322, 0.5291),
                                                           (0.3302, 0.3432, 0.3701))
                                      ])
#image = get_image('/home/jp/Desktop/archive/dataset/testejp.jpeg',False)

img = cv2.imread('/home/jp/Desktop/archive/dataset/testejp.jpeg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img = cv2.resize(img,(32,32))

plt.imshow(img)

img_as_tensor = transformations(img)

print(img_as_tensor)

img = img_as_tensor.permute(1,2,0)
plt.imshow(img)

s = nn.Softmax(dim=1)

out = s(model(img.unsqueeze(0).to(device)))
print('Prediction: {}'.format(out))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor([[[-0.2457, -0.3169, -0.3407,  ...,  0.0869, -0.1982, -0.0200],
#          [ 0.0275,  0.0275,  0.0037,  ..., -0.1863, -0.1625, -0.1150],
#          [ 0.2056,  0.2769,  0.0987,  ...,  0.0750, -0.1150, -0.0438],
#          ...,
#          [-0.2932, -0.3644, -0.2338,  ..., -0.1744,  0.0156,  0.1225],
#          [-0.3644, -0.4119, -0.4119,  ..., -0.2457, -0.2100, -0.0556],
#          [-0.5069, -0.4594, -0.4357,  ..., -0.3407, -0.2575, -0.0794]],
#
#         [[-0.0367, -0.1510, -0.1852,  ...,  0.2718, -0.0367,  0.1347],
#          [ 0.1690,  0.1690,  0.1233,  ..., -0.0367, -0.0024,  0.0547],
#          [ 0.3404,  0.4089,  0.2147,  ...,  0.2261,  0.0319,  0.1233],
#          ...,
#          [-0.1967, -0.2652, -0.1395,  ...,  0.0090,  0.1918,  0.2718],
#          [-0.2538, -0.2995, -0.3109,  ..., -0.0710, -0.0595,  0.0890],
#          [-0.3909, -0.3566, -0.3109,  ..., -0.1281, -0.1052,  0.0776]],
#
#         [[ 0.1598, -0.0309, -0.0627,  ...,  0.3505,  0.0962,  0.2340],
#          [ 0.2551,  0.2551,  0.1916,  ...,  0.0644,  0.1068,  0.1280],
#          [ 0.4035,  0.4777,  0.2763,  ...,  0.3187,  0.1280,  0.2022],
#          ...,
#          [-0.1581, -0.2217, -0.1051,  ...,  0.1916,  0.3505,  0.3823],
#          [-0.2217, -0.2747, -0.2641,  ...,  0.1492,  0.1386,  0.2022],
#          [-0.3594, -0.3064, -0.2747,  ...,  0.1280,  0.1174,  0.2022]]])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-111-c18eccf3fca1> in <module>
#      30 s = nn.Softmax(dim=1)
#      31
# ---> 32 out = s(model(img.unsqueeze(0).to(device)))
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# <ipython-input-66-ea0d8bb06c07> in forward(self, x)
#       7         self.fc2 = nn.Linear(32,2)
#       8     def forward(self,x):
# ----> 9         out = F.max_pool2d(torch.tanh(self.conv1(x)),2)
#      10         out = F.max_pool2d(torch.tanh(self.conv2(out)),2)
#      11         out = out.view(-1,8*8*8)
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     417
#     418     def forward(self, input: Tensor) -> Tensor:
# --> 419         return self._conv_forward(input, self.weight)
#     420
#     421 class Conv3d(_ConvNd):
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight)
#     413                             weight, self.bias, self.stride,
#     414                             _pair(0), self.dilation, self.groups)
# --> 415         return F.conv2d(input, weight, self.bias, self.stride,
#     416                         self.padding, self.dilation, self.groups)
#     417
#
# RuntimeError: Given groups=1, weight of size [16, 3, 3, 3], expected input[1, 32, 32, 3] to have 3 channels, but got 32 channels instead
